# %%
import pandas as pd

# %%
GK=pd.read_csv('fifa.GK.UTF.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 89 columns):
# Unnamed: 0                  2025 non-null int64
# ID                          2025 non-null int64
# Name                        2025 non-null object
# Age                         2025 non-null int64
# Photo                       2025 non-null object
# Nationality                 2025 non-null object
# Flag                        2025 non-null object
# Overall                     2025 non-null int64
# Potential                   2025 non-null int64
# Club                        1992 non-null object
# Club.Logo                   2025 non-null object
# Value                       2025 non-null object
# Wage                        2025 non-null object
# Special                     2025 non-null int64
# Preferred.Foot              2025 non-null object
# International.Reputation    2025 non-null int64
# Weak.Foot                   2025 non-null int64
# ...

# %%
df = pd.DataFrame(GK,
                  columns=['GKDiving'],
                  index=np.arange(0, 2024,40))
df.plot()

# %%
df = pd.DataFrame(GK,
                  columns=['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning','GKReflexes'],
                  index=np.arange(0, 2024,40))
df.plot()

# %%
GK['GKDiving'].mean()
# Out:
# 65.32395061728396

# %%
GK['GKHandling'].mean()
# Out:
# 62.86814814814815

# %%
GK['GKKicking'].mean()
# Out:
# 61.47753086419753

# %%
GK['GKPositioning'].mean()
# Out:
# 63.047407407407405

# %%
GK['GKReflexes'].mean()
# Out:
# 66.10172839506173

# %%
MGK = pd.DataFrame(['65.32395061728396','62.86814814814815','61.47753086419753','63.047407407407405','66.10172839506173'],
                  index=['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
                  columns=pd.Index(['mean']))

# %%
MGK
# Out:
#                              mean
# GKDiving        65.32395061728396
# GKHandling      62.86814814814815
# GKKicking       61.47753086419753
# GKPositioning  63.047407407407405
# GKReflexes      66.10172839506173

# %%
### 데이터 상위 10퍼센트, 하위 10퍼센트 데이터 나누기

# %%
GK.head()
# Out:
#    Unnamed: 0      ID           Name  Age  \
# 0           1  193080         De Gea   27
# 1           2  200389       J. Oblak   25
# 2           3  192448  M. ter Stegen   26
# 3           4  192119    T. Courtois   26
# 4           5  167495       M. Neuer   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 1  https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 2  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 3  https://cdn.sofifa.org/players/4/19/192119.png     Belgium
# 4  https://cdn.sofifa.org/players/4/19/167495.png     Germany
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
# 1  https://cdn.sofifa.org/flags/44.png       90         93    Atl?tico Madrid
# 2  https://cdn.sofifa.org/flags/21.png       89         92       FC Barcelona
# ...

# %%
GK.tail()
# Out:
#       Unnamed: 0      ID           Name  Age  \
# 2020        2021  243158   L. Wahlstedt   18
# 2021        2022  221669       M. Hurst   22
# 2022        2023   53748  K. Pilkington   44
# 2023        2024  245862       J. Milli   18
# 2024        2025  242844     J. Livesey   18
#
#                                                Photo Nationality  \
# 2020  https://cdn.sofifa.org/players/4/19/243158.png      Sweden
# 2021  https://cdn.sofifa.org/players/4/19/221669.png    Scotland
# 2022   https://cdn.sofifa.org/players/4/19/53748.png     England
# 2023  https://cdn.sofifa.org/players/4/19/245862.png       Italy
# 2024  https://cdn.sofifa.org/players/4/19/242844.png     England
#
#                                      Flag  Overall  Potential  \
# 2020  https://cdn.sofifa.org/flags/46.png       48         65
# 2021  https://cdn.sofifa.org/flags/42.png       48         58
# 2022  https://cdn.sofifa.org/flags/14.png       48         48
# ...

# %%
GK.U=GK.iloc[0:200]

# %%
GK.U.head()
# Out:
#    Unnamed: 0      ID           Name  Age  \
# 0           1  193080         De Gea   27
# 1           2  200389       J. Oblak   25
# 2           3  192448  M. ter Stegen   26
# 3           4  192119    T. Courtois   26
# 4           5  167495       M. Neuer   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 1  https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 2  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 3  https://cdn.sofifa.org/players/4/19/192119.png     Belgium
# 4  https://cdn.sofifa.org/players/4/19/167495.png     Germany
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
# 1  https://cdn.sofifa.org/flags/44.png       90         93    Atl?tico Madrid
# 2  https://cdn.sofifa.org/flags/21.png       89         92       FC Barcelona
# ...

# %%
GK.U.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 89 columns):
# Unnamed: 0                  200 non-null int64
# ID                          200 non-null int64
# Name                        200 non-null object
# Age                         200 non-null int64
# Photo                       200 non-null object
# Nationality                 200 non-null object
# Flag                        200 non-null object
# Overall                     200 non-null int64
# Potential                   200 non-null int64
# Club                        198 non-null object
# Club.Logo                   200 non-null object
# Value                       200 non-null object
# Wage                        200 non-null object
# Special                     200 non-null int64
# Preferred.Foot              200 non-null object
# International.Reputation    200 non-null int64
# Weak.Foot                   200 non-null int64
# ...

# %%
GK.L=GK.iloc[1825:]

# %%
GK.L.tail()
# Out:
#       Unnamed: 0      ID           Name  Age  \
# 2020        2021  243158   L. Wahlstedt   18
# 2021        2022  221669       M. Hurst   22
# 2022        2023   53748  K. Pilkington   44
# 2023        2024  245862       J. Milli   18
# 2024        2025  242844     J. Livesey   18
#
#                                                Photo Nationality  \
# 2020  https://cdn.sofifa.org/players/4/19/243158.png      Sweden
# 2021  https://cdn.sofifa.org/players/4/19/221669.png    Scotland
# 2022   https://cdn.sofifa.org/players/4/19/53748.png     England
# 2023  https://cdn.sofifa.org/players/4/19/245862.png       Italy
# 2024  https://cdn.sofifa.org/players/4/19/242844.png     England
#
#                                      Flag  Overall  Potential  \
# 2020  https://cdn.sofifa.org/flags/46.png       48         65
# 2021  https://cdn.sofifa.org/flags/42.png       48         58
# 2022  https://cdn.sofifa.org/flags/14.png       48         48
# ...

# %%
GK.L.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 1825 to 2024
# Data columns (total 89 columns):
# Unnamed: 0                  200 non-null int64
# ID                          200 non-null int64
# Name                        200 non-null object
# Age                         200 non-null int64
# Photo                       200 non-null object
# Nationality                 200 non-null object
# Flag                        200 non-null object
# Overall                     200 non-null int64
# Potential                   200 non-null int64
# Club                        200 non-null object
# Club.Logo                   200 non-null object
# Value                       200 non-null object
# Wage                        200 non-null object
# Special                     200 non-null int64
# Preferred.Foot              200 non-null object
# International.Reputation    200 non-null int64
# Weak.Foot                   200 non-null int64
# ...

# %%
### 상위 하위 비교 그래프

# %%
df = pd.DataFrame(GK.U,
                  columns=['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning','GKReflexes'],
                  index=np.arange(0, 200,10))
df.plot()

# %%
df = pd.DataFrame(GK.L,
                  columns=['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning','GKReflexes'],
                  index=np.arange(0, 200,10))
df.plot()
